# %% [markdown]
# <a href="https://colab.research.google.com/github/tanongsakintean/google_colab/blob/main/Lab_06_6406021622095.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Workshop 6: Clean Missing Data**
# **คำสั่ง**
#
# 1.   ศึกษาวิธีการเติมข้อมูลสูญหายเบื้องต้นต่อไปนี้
# 2.   ทำการเติมข้อมูลสูญหายทุกตัวแปรด้วยวิธีที่เหมาะสม
# 3.   ตั้งชื่อไฟล์ python notebook นี้ในรูปแบบ Lab_06_XXXXXXXXXXXXX.ipynb โดย XXXXXXXXX คือ รหัสนักศึกษา
# 4.   ทำการดาวน์โหลดและส่งไฟล์ Lab_06_XXXXXXXXXXXXX.ipynb ที่ Google Classroom

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
nfl_data = pd.read_csv("/content/drive/MyDrive/DATASET/NFL.csv")
nfl_data.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <ipython-input-4-3abaa8ba9556>:3: DtypeWarning: Columns (51) have mixed types. Specify dtype option on import or set low_memory=False.
#   nfl_data = pd.read_csv("/content/drive/MyDrive/DATASET/NFL.csv")
#         Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  9/10/2009  2009091000      1    1   NaN  15:00         15    3600.0
# 1  9/10/2009  2009091000      1    1   1.0  14:53         15    3593.0
# 2  9/10/2009  2009091000      1    1   2.0  14:16         15    3556.0
# 3  9/10/2009  2009091000      1    1   3.0  13:35         14    3515.0
# 4  9/10/2009  2009091000      1    1   4.0  13:27         14    3507.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...       NaN     0.485675     0.514325
# 1           7.0         PIT  ...  1.146076     0.546433     0.453567
# ...

# %% [markdown]
# **Check missing data**

# %%
# get the number of missing data points per column
missing_values_count = nfl_data.isnull().sum()

# look at the # of missing points in the first ten columns
missing_values_count[0:10]
# Out:
# Date               0
# GameID             0
# Drive              0
# qtr                0
# down            6409
# time              29
# TimeUnder          0
# TimeSecs          29
# PlayTimeDiff      58
# SideofField       55
# dtype: int64

# %%
# how many total missing values do we have?
total_cells = np.product(nfl_data.shape)
total_missing = missing_values_count.sum()

# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 27.769186471150064

# %% [markdown]
# **Drop missing values**

# %%
# remove all the rows that contain a missing value
nfl_data.dropna()
# Out:
# Empty DataFrame
# ...

# %%
# remove all the rows that contain a missing value in specific columns
nfl_data.dropna(subset=['down'])
# Out:
#              Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 1       9/10/2009  2009091000      1    1   1.0  14:53         15    3593.0
# 2       9/10/2009  2009091000      1    1   2.0  14:16         15    3556.0
# 3       9/10/2009  2009091000      1    1   3.0  13:35         14    3515.0
# 4       9/10/2009  2009091000      1    1   4.0  13:27         14    3507.0
# 5       9/10/2009  2009091000      2    1   1.0  13:16         14    3496.0
# ...           ...         ...    ...  ...   ...    ...        ...       ...
# 41875  12/28/2009  2009122800     26    5   3.0  10:27         11    -273.0
# 41876  12/28/2009  2009122800     26    5   4.0  10:22         11    -278.0
# 41877  12/28/2009  2009122800     27    5   1.0  10:11         11    -289.0
# 41878  12/28/2009  2009122800     27    5   2.0   9:32         10    -328.0
# 41879  12/28/2009  2009122800     28    5   1.0   9:21         10    -339.0
#
# ...

# %%
# remove all columns with at least one missing value
nfl_data.dropna(axis=1)
# Out:
#              Date      GameID  Drive  qtr  TimeUnder  ydstogo  ydsnet  \
# 0       9/10/2009  2009091000      1    1         15        0       0
# 1       9/10/2009  2009091000      1    1         15       10       5
# 2       9/10/2009  2009091000      1    1         15        5       2
# 3       9/10/2009  2009091000      1    1         14        8       2
# 4       9/10/2009  2009091000      1    1         14        8       2
# ...           ...         ...    ...  ...        ...      ...     ...
# 41875  12/28/2009  2009122800     26    5         11        7       3
# 41876  12/28/2009  2009122800     26    5         11        7       3
# 41877  12/28/2009  2009122800     27    5         11       10       0
# 41878  12/28/2009  2009122800     27    5         10       10      16
# 41879  12/28/2009  2009122800     28    5         10       10      39
#
#                                                     desc  PlayAttempted  \
# ...

# %% [markdown]
# **Impute missing data**

# %%
# fill all missing with a value
results = nfl_data.fillna(0)
results.isnull().sum()
# Out:
# Date        0
# GameID      0
# Drive       0
# qtr         0
# down        0
#            ..
# Win_Prob    0
# WPA         0
# airWPA      0
# yacWPA      0
# Season      0
# Length: 102, dtype: int64

# %%
# fill missing values in a specific column with a value
results = nfl_data
results['down'].fillna(0, inplace = True)
results.isnull().sum()
# Out:
# Date            0
# GameID          0
# Drive           0
# qtr             0
# down            0
#             ...
# Win_Prob     2767
# WPA           643
# airWPA      25919
# yacWPA      25943
# Season          0
# Length: 102, dtype: int64

# %%
# fill missing values in a specific column with mean
results = nfl_data
results['down'].fillna(results['down'].mean(), inplace = True)
results.isnull().sum()
# Out:
# Date            0
# GameID          0
# Drive           0
# qtr             0
# down            0
#             ...
# Win_Prob     2767
# WPA           643
# airWPA      25919
# yacWPA      25943
# Season          0
# Length: 102, dtype: int64

# %% [markdown]
# ปฏิบัติการข้อ 1) ให้นักศึกษาเติมข้อมูลสูญหายของตัวแปรทั้งหมดที่มีข้อมูลสูญหาย จะใช้วิธีการใดก็ได้ ตามความเหมาะสม พร้อมเขียนอธิบาย

# %%
# Answer here!
#fill missing values in a specific column with mean
#เพราะใช้เนื่องจาก percent missing มีถึง ~ 27% ดังนั้นจึงใช้การหาค่าเฉลี่ยแทน

preprocessData = nfl_data
preprocessData['airWPA'].fillna(preprocessData['airWPA'].mean(), inplace = True)
preprocessData['yacWPA'].fillna(preprocessData['yacWPA'].mean(), inplace = True)
preprocessData.isnull().sum()
preprocessData.shape
# Out:
# (41880, 102)
